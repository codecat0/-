# %% [markdown]
# ## Figure和Subplot

# %%
fig = plt.figure()

ax1 = fig.add_subplot(2,2,1)

ax2 = fig.add_subplot(2,2,2)

ax3 = fig.add_subplot(2,2,3)

# %%
from numpy.random import randn

ax1.plot(randn(50).cumsum(),'k--')

_ = ax2.hist(randn(100),bins=20,color='r',alpha=0.3)

ax3.scatter(np.arange(30),np.arange(30)+3*randn(30))

# %%
fig

# %% [markdown]
# ## 颜色，标记和线型

# %%
plt.plot(randn(30).cumsum(),'ko--')

# %%
data = randn(30).cumsum()

data
# Out:
# array([ -2.05343684,  -4.06519272,  -4.46513092,  -2.01525699,
#         -1.01143026,  -0.37507049,  -1.0677122 ,  -3.34800967,
#         -4.57188782,  -6.35826042,  -7.47641358,  -9.20352809,
#         -7.54346271,  -6.09295545,  -6.19227099,  -6.77347524,
#         -7.66589716,  -7.88633272,  -8.7260907 ,  -8.39314837,
#         -7.6705144 ,  -8.4447684 ,  -8.94512981,  -7.85460288,
#         -8.18626314,  -9.4282288 ,  -8.44501321,  -7.00478327,
#         -9.32560402, -11.26559359])

# %%
plt.plot(data,'k--',label='Default')

# %%
plt.plot(data,'r-',drawstyle='steps-post',label='steps-post')

# %% [markdown]
# ## 设置标题，轴标签，刻度和刻度标签

# %%
fig = plt.figure()

ax = fig.add_subplot(1,1,1)

ax.plot(randn(100).cumsum())

# %%
ticks = ax.set_xticks([0,25,50,75,100])

labels = ax.set_xticklabels(['one','two0','three','four','five'],rotation=30,fontsize='small')

# %%
fig

# %%
ax.set_title('my first matplotlib plot')
# Out:
# Text(0.5, 1.0, 'my first matplotlib plot')

# %%
ax.set_xlabel('Stages')
# Out:
# Text(0.5, 3.200000000000003, 'Stages')

# %%
fig

# %% [markdown]
# ## 添加图例

# %%
fig = plt.figure()

ax = fig.add_subplot(1,1,1)

ax.plot(randn(1000).cumsum(),'k',label='one')

# %%
ax.plot(randn(1000).cumsum(),'r--',label='two')

# %%
ax.plot(randn(1000).cumsum(),'b.',label='three')

# %%
ax.legend(loc='best')

# %%
fig

# %% [markdown]
# ## 注解

# %%
fig = plt.figure()

ax = fig.add_subplot(1,1,1)

ax.plot(randn(100).cumsum())

# %%
ax.annotate('vaule of best',(40,-4.8),xytext=(20,-12.5),arrowprops=dict(arrowstyle='->'))
# Out:
# Text(20, -12.5, 'vaule of best')

# %%
fig

# %% [markdown]
# ## 图的保存

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

rect = plt.Rectangle((0.2,0.75),0.4,0.15,color='k',alpha=0.3)
circ = plt.Circle((0.7,0.2),0.15,color='b',alpha=0.3)
pgon = plt.Polygon([[0.15,0.15],[0.35,0.4],[0.2,0.6]],color='g',alpha=0.5)

ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %%
plt.savefig('figpath.svg')

# %% [markdown]
# ## pandas中的绘图函数

# %%
import pandas as pd

# %%
s = pd.Series(np.random.randn(10).cumsum(),index=np.arange(0,100,10))

s.plot()

# %%
df = pd.DataFrame(np.random.randn(10,4).cumsum(0),columns=['A','B','C','D'],index=np.arange(0,100,10))

df.plot()
